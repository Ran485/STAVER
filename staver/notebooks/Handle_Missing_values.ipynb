# %%
import pandas as pd
import numpy as np

from MissingValueHandler import MissingValueHandler

# %%
data = pd.read_csv('/Volumes/T7_Shield/staver/results/DIA_repeat20/merge_datas/Protein_matrix.csv', index_col=0)
data
# Out:
#             Exp000000_DingC_PooledQC_DIA_3_HFX5_10min_8cm_2per_20210617_F1_R1  \
# Gene_ID
# A0A075B6H7                                       6.215694e+07
# A0A075B6H9                                       7.966326e+04
# A0A075B6I0                                       5.632925e+06
# A0A075B6I9                                       1.149283e+07
# A0A075B6J9                                       3.865747e+06
# ...                                                       ...
# Q9NZI2                                                    NaN
# Q9P2K3                                                    NaN
# Q9ULT0                                                    NaN
# Q9UPN6                                                    NaN
# Q9Y6M7                                                    NaN
#
#             Exp000000_DingC_PooledQC_DIA_4_HFX5_10min_8cm_2per_20210617_F1_R1  \
# Gene_ID
# A0A075B6H7                                       7.045379e+07
# ...

# %%
missing_value_handler = MissingValueHandler()
missing_value_handler

# %%
# data1 = missing_value_handler.remove_rows_below_threshold()
data1 = missing_value_handler.remove_rows_below_threshold(data, threshold=0.3)
data1
# Out:
#             Exp000000_DingC_PooledQC_DIA_3_HFX5_10min_8cm_2per_20210617_F1_R1  \
# Gene_ID
# A0A075B6H7                                       6.215694e+07
# A0A075B6H9                                       7.966326e+04
# A0A075B6I0                                       5.632925e+06
# A0A075B6I9                                       1.149283e+07
# A0A075B6J9                                       3.865747e+06
# ...                                                       ...
# Q15046                                                    NaN
# Q7L775                                                    NaN
# Q9Y646                                                    NaN
# O43493                                                    NaN
# P78344                                                    NaN
#
#             Exp000000_DingC_PooledQC_DIA_4_HFX5_10min_8cm_2per_20210617_F1_R1  \
# Gene_ID
# A0A075B6H7                                       7.045379e+07
# ...

# %%
data1.to_csv("/Volumes/T7_Shield/staver/results/DIA_repeat203/merge_datas/Protein_matrix_Dropna_30%.csv")

# %%
data2 = missing_value_handler.knn_impute_missing_values(data1, n_neighbors=5)
data2
# Out:
#             Exp000000_DingC_PooledQC_DIA_3_HFX5_10min_8cm_2per_20210617_F1_R1  \
# Gene_ID
# A0A075B6H7                                       6.215694e+07
# A0A075B6H9                                       7.966326e+04
# A0A075B6I0                                       5.632925e+06
# A0A075B6I9                                       1.149283e+07
# A0A075B6J9                                       3.865747e+06
# ...                                                       ...
# Q15046                                           5.041194e+06
# Q7L775                                           1.191753e+08
# Q9Y646                                           1.210959e+08
# O43493                                           2.934386e+05
# P78344                                           5.755514e+06
#
#             Exp000000_DingC_PooledQC_DIA_4_HFX5_10min_8cm_2per_20210617_F1_R1  \
# Gene_ID
# A0A075B6H7                                       7.045379e+07
# ...

# %%
data2.to_csv("/Volumes/T7_Shield/staver/results/DIA_repeat203/merge_datas/Protein_matrix_Dropna_30%_KNN5.csv")

# %%
def caculate_cv(data):
    cv = data.std(axis = 1) / data.mean(axis = 1)
    return pd.DataFrame(cv, columns = ['Coefficient of variation'])

# %%
caculate_cv(data2)
# Out:
#             Coefficient of variation
# Gene_ID
# A0A075B6H7                  0.062864
# A0A075B6H9                  0.274942
# A0A075B6I0                  0.134195
# A0A075B6I9                  0.091038
# A0A075B6J9                  0.107497
# ...                              ...
# Q15046                      0.520852
# Q7L775                      2.019802
# Q9Y646                      1.853943
# O43493                      2.410108
# P78344                      2.773035
#
# [2580 rows x 1 columns]

# %%
caculate_cv(data2).median(axis=0)
# Out:
# Coefficient of variation    0.685406
# dtype: float64

# %%
caculate_cv(data1).median(axis=0)
# Out:
# Coefficient of variation    0.572245
# dtype: float64

# %%
df = pd.read_csv("../results/DIA_repeat20/peptides/high_confidence_peptide_of_diff_files_top3_coefficient_top3.csv")
df
# Out:
#                                                    index  \
# 0      A0A075B6H7;A0A0C4DH55;P01624_LLIYGASTR_LLIYGAS...
# 1      A0A075B6H7;A0A0C4DH55;P01624_LLIYGASTR_LLIYGAS...
# 2      A0A075B6H7;A0A0C4DH55;P01624_LLIYGASTR_LLIYGAS...
# 3      A0A075B6H7_EIVMTQSPPTLSLSPGER_EIVMTQSPPTLSLSPG...
# 4      A0A075B6H7_EIVMTQSPPTLSLSPGER_EIVMTQSPPTLSLSPG...
# ...                                                  ...
# 29088  Q9Y6Z7_DEAANTLIADYVAK_DEAANTLIADYVAK_DEAANTLIA...
# 29089  Q9Y6Z7_DEAANTLIADYVAK_DEAANTLIADYVAK_DEAANTLIA...
# 29090  Q9Y6Z7_DEAANTLIADYVAK_DEAANTLIADYVAK_DEAANTLIA...
# 29091  Q9Y6Z7_DEAANTLIADYVAK_DEAANTLIADYVAK_DEAANTLIA...
# 29092  Q9Y6Z7_DEAANTLIADYVAK_DEAANTLIADYVAK_DEAANTLIA...
#
#                                                file_name         mean  \
# 0      Exp000000_DingC_PooledQC_DIA_HFX5_10min_8cm_2p...  94010920.00
# 1      Exp000000_DingC_PooledQC_DIA_HFX5_10min_8cm_2p...  93919090.00
# ...
